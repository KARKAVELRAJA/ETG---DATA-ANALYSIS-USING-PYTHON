# %% [markdown]
# **ANALYSIS OF SUMMER OLYMPICS DATASET**

# %% [markdown]
# **IMPORTING REQUIRED PYTHON LIBRARIES FOR PERFORMING DATA ANALYSIS**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **LOADING THE summer.csv FILE INTO THE DATAFRAME USING PANDAS LIBRARY**

# %%
df = pd.read_csv("summer.csv") 
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %% [markdown]
#  **DATA PRE-PROCESSING**

# %% [markdown]
# * Removing the **UNNECESSARY COLUMNS**

# %%
del df['Discipline']
df
# Out:
#        Year    City      Sport                            Athlete Country  \
# 0      1896  Athens   Aquatics                      HAJOS, Alfred     HUN
# 1      1896  Athens   Aquatics                   HERSCHMANN, Otto     AUT
# 2      1896  Athens   Aquatics                  DRIVAS, Dimitrios     GRE
# 3      1896  Athens   Aquatics                 MALOKINIS, Ioannis     GRE
# 4      1896  Athens   Aquatics                 CHASAPIS, Spiridon     GRE
# 5      1896  Athens   Aquatics              CHOROPHAS, Efstathios     GRE
# 6      1896  Athens   Aquatics                      HAJOS, Alfred     HUN
# 7      1896  Athens   Aquatics                   ANDREOU, Joannis     GRE
# 8      1896  Athens   Aquatics              CHOROPHAS, Efstathios     GRE
# 9      1896  Athens   Aquatics                      NEUMANN, Paul     AUT
# 10     1896  Athens   Aquatics                  PEPANOS, Antonios     GRE
# 11     1896  Athens  Athletics                      LANE, Francis     USA
# ...

# %% [markdown]
# * Removing the **NULL VALUES** from the dataset

# %%
df.isnull().sum()
# Out:
# Year       0
# City       0
# Sport      0
# Athlete    0
# Country    4
# Gender     0
# Event      0
# Medal      0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#        Year    City      Sport                            Athlete Country  \
# 0      1896  Athens   Aquatics                      HAJOS, Alfred     HUN
# 1      1896  Athens   Aquatics                   HERSCHMANN, Otto     AUT
# 2      1896  Athens   Aquatics                  DRIVAS, Dimitrios     GRE
# 3      1896  Athens   Aquatics                 MALOKINIS, Ioannis     GRE
# 4      1896  Athens   Aquatics                 CHASAPIS, Spiridon     GRE
# 5      1896  Athens   Aquatics              CHOROPHAS, Efstathios     GRE
# 6      1896  Athens   Aquatics                      HAJOS, Alfred     HUN
# 7      1896  Athens   Aquatics                   ANDREOU, Joannis     GRE
# 8      1896  Athens   Aquatics              CHOROPHAS, Efstathios     GRE
# 9      1896  Athens   Aquatics                      NEUMANN, Paul     AUT
# 10     1896  Athens   Aquatics                  PEPANOS, Antonios     GRE
# 11     1896  Athens  Athletics                      LANE, Francis     USA
# ...

# %% [markdown]
# # **SUMMER OLYMPICS DATA ANALYSIS**

# %% [markdown]
# ### **1. In how many cities Summer Olympics is held so far?**

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# ###Summer Olympics held in **22** cities so far

# %% [markdown]
# ### **2. Which sport is having most number of Gold Medals so far? (Top 5)**

# %%
df_gold_medal = df[df['Medal'] == 'Gold']
 
lst = []
for i in df_gold_medal['Sport'].unique():
     lst.append([i, len(df_gold_medal[df_gold_medal['Sport'] == i])])
 
pd.DataFrame(lst, columns = ['Sport','Gold_Medals']).sort_values(by = 'Gold_Medals', ascending = False).head().plot.bar(x = 'Sport', y = 'Gold_Medals')

# %% [markdown]
# ###**Aquatics, Athletics, Rowing, Gymnastics, Fencing** are the sports which are having most number of **Gold Medals** so far

# %% [markdown]
# ### **3. Which sport is having most number of medals so far? (Top 5)**

# %%
lsts = []
for i in df['Sport'].unique():
     lsts.append([i, len(df[df['Sport'] == i])])
 
pd.DataFrame(lsts, columns = ['Sport','Medals']).sort_values(by = 'Medals', ascending = False).head().plot.bar(x = 'Sport', y = 'Medals')

# %% [markdown]
# ###**Aquatics, Athletics, Rowing, Gymnastics, Fencing** are the sports which are having most number of **Medals** so far

# %% [markdown]
# ### **4. Which player has won most number of medals? (Top 5)**

# %%
lstss = []
for i in df['Athlete'].unique():
     lstss.append([i, len(df[df['Athlete'] == i])])
 
pd.DataFrame(lstss, columns = ['Player', 'Medals']).sort_values(by = 'Medals', ascending = False).head().plot.bar(x = 'Player' , y = 'Medals')

# %% [markdown]
# ###**"PHELIPS, Michael", "LATYNINA, Larisa", "ANDRIANOV, Nikolay", "SHAKHLIN, Boris", "ONO, Takashi"** are the players who won most number of **Medals**

# %% [markdown]
# ### **5. Which player has won most number of Gold Medals? (Top 5)**

# %%
df_gold_medals = df[df['Medal'] == 'Gold']
 
lstsss = []
for i in df_gold_medals['Athlete'].unique():
     lstsss.append([i, len(df_gold_medals[df_gold_medals['Athlete'] == i])])
 
pd.DataFrame(lstsss, columns = ['Player','Gold_Medals']).sort_values(by = 'Gold_Medals', ascending = False).head().plot.bar(x = 'Player' , y = 'Gold_Medals')

# %% [markdown]
# ###**"PHELIPS, Michael", "LEWIS, Carl", "NURMI, Paavo", "LATYNINA, Larisa", "SPITZ, Mark"** are the players who won most number of **Gold Medals**

# %% [markdown]
# ### **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
df_Gold_Medal = df[df['Medal'] == 'Gold']
df_Gold_India = df_Gold_Medal[df_Gold_Medal['Country'] == 'IND']
 
lstt = []
for i in df_Gold_India['Year'].unique():
     lstt.append(i)
min(lstt)
# Out:
# 1928

# %% [markdown]
#  ### In **1928** India won first Gold Medal in Summer Olympics

# %% [markdown]
# ### **7. Which event is most popular in terms on number of players? (Top 5)**

# %%
lstssss = []
for i in df['Event'].unique():
     lstssss.append([i, len(df[df['Event'] == i])])
 
pd.DataFrame(lstssss,columns = ['Event','Total_Players']).sort_values(by = 'Total_Players', ascending = False).head().plot.bar(x = 'Event', y = 'Total_Players')

# %% [markdown]
# ###**Football, Hockey, Team Competition, Basketball, Handball** are the most popular **Events** in terms of number of players

# %% [markdown]
# ### **8. Which sport is having most female Gold Medalists? (Top 5)**

# %%
df_gold_medalss = df[df['Medal'] == 'Gold']
df_gold_women = df_gold_medalss[df_gold_medalss['Gender'] == 'Women']
 
lstsssss = []
for i in df_gold_women['Sport'].unique():
     lstsssss.append([i,len(df_gold_women[df_gold_women['Sport'] == i])])
 
pd.DataFrame(lstsssss, columns = ['Sport', 'Gold_Medals_For_Female']).sort_values(by = 'Gold_Medals_For_Female', ascending = False).head().plot.bar(x = 'Sport', y = 'Gold_Medals_For_Female')

# %% [markdown]
# ###**Aquatics, Athletics, Gymnastics, Rowing, Volleyball** are the sports which are having the most number of **Female Gold Medalists**
